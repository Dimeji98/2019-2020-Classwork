# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
combine_data = pd.read_csv('combine_data_since_2000_PROCESSED_2018-04-26.csv', engine = "python")
combine_data.loc[(combine_data.Pos == 'G'),'Pos']='OG'
combine_data.loc[(combine_data.Pos == 'FS'),'Pos']='S'
combine_data.loc[(combine_data.Pos == 'SS'),'Pos']='S'
combine_data.loc[(combine_data.Pos == 'ILB'),'Pos']='LB'
combine_data.loc[(combine_data.Pos == 'OLB'),'Pos']='LB'
combine_data.loc[(combine_data.Pos == 'NT'),'Pos']='DT'
combine_data.loc[(combine_data.Pos == 'DB'),'Pos']='CB'
combine_data.loc[(combine_data.Pos == 'OL'),'Pos']='OG'
#Found some positions ere redundant so I groupd them together when appropriate.

WR=combine_data[combine_data['Pos']=='WR']
CB=combine_data[combine_data['Pos']=='CB']
RB=combine_data[combine_data['Pos']=='RB']
DE=combine_data[combine_data['Pos']=='DE']
DT=combine_data[combine_data['Pos']=='DT']
OT=combine_data[combine_data['Pos']=='OT']
OG=combine_data[combine_data['Pos']=='OG']
QB=combine_data[combine_data['Pos']=='QB']
TE=combine_data[combine_data['Pos']=='TE']
C=combine_data[combine_data['Pos']=='C']
P=combine_data[combine_data['Pos']=='P']
FB=combine_data[combine_data['Pos']=='FB']
K=combine_data[combine_data['Pos']=='K']
S=combine_data[combine_data['Pos']=='S']
EDGE=combine_data[combine_data['Pos']=='EDGE']
LS=combine_data[combine_data['Pos']=='LS']
LB=combine_data[combine_data['Pos']=='LB']
DB=combine_data[combine_data['Pos']=='DB']
OL=combine_data[combine_data['Pos']=='OL']
#Subsetted each position group into its own dataframe

# %%
#####################GRAPHS

#The functions forty, bench, vertical, height, weight, bj, cone, and shuttle all create piecharts for the data set by position. 
#Each of the functions takes the values and sorts them in catergories of ranges to display on the bar graph
#The user is prompt on which position and variable they would like to look at 

# This function initates the pie chart
def pie(x,y):
        labels = x
        sizes = y
        fig1, ax1 = plt.subplots()
        ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
        ax1.axis('equal')  
        plt.show()

#This is the function inside all the other test functions that turn it into a circle graph
def circle_graph(a,b):        
    data=pd.DataFrame.from_dict(a, orient='index', columns=["count"])
    data['perc'] = data['count']/len(b)
    real_data= data[data["perc"]!=0]
    pie(real_data.index, real_data['perc'])


####################################### Forty Pie Chart    
def forty_test():
    def grap(): 
        Under4_3=0
        Under4_4=0
        Under4_5=0
        Under4_6=0
        Under4_7=0
        Under4_8=0
        Under4_9=0
        above_equal=0
        total_forty=list()
        for forty in bench_list:
            if forty<4.3:
                Under4_3=Under4_3+1 
            if (forty >4.3) and (forty <4.4):
                Under4_4=Under4_4+1 
            if (forty >4.4) and (forty <4.5):
                Under4_5=Under4_5+1 
            if (forty >4.5) and (forty <4.6):
                Under4_6=Under4_6+1 
            if (forty >4.6) and (forty <4.7):
                Under4_7=Under4_7+1 
            if (forty >4.7) and (forty <4.8):
                Under4_8=Under4_8+1 
            if (forty >4.8) and (forty <4.9):
                Under4_9=Under4_9+1 
            if forty>=5.0:
                above_equal=above_equal+1 
        total_forty.append(Under4_3)
        total_forty.append(Under4_4)
        total_forty.append(Under4_5)
        total_forty.append(Under4_6)
        total_forty.append(Under4_7)
        total_forty.append(Under4_8)
        total_forty.append(Under4_9)
        total_forty.append(above_equal)
        forty_dict=['Sub 4.3','Sub 4.4','Sub 4.5','Sub 4.6','Sub 4.7', 'Sub 4.8', 'Sub 4.9', '5 and above']
        dict_forty = dict(zip(forty_dict, total_forty))
        circle_graph(dict_forty, total_forty)
    position=input('What position group would you like to focus on? ')
    position.lower()
    if position=='CB':
        bench_list=CB['Forty'].tolist()
        grap()
    if position=='WR':
        bench_list=WR['Forty'].tolist()
        grap()
    if position=='QB':
        bench_list=QB['Forty'].tolist()
        grap()
    if position=='RB':
        bench_list=RB['Forty'].tolist()
        grap()
    if position=='DE':
        bench_list=DE['Forty'].tolist()
        grap()
    if position=='DT':
        bench_list=DT['Forty'].tolist()
        grap()
    if position=='OT':
        bench_list=OT['Forty'].tolist()
        grap()
    if position=='LB':
        bench_list=LB['Forty'].tolist()
        grap()
    if position=='OG':
        bench_list=OG['Forty'].tolist()
        grap()
    if position=='TE':
        bench_list=TE['Forty'].tolist()
        grap()
    if position=='C':
        bench_list=C['Forty'].tolist()
        grap()
    if position=='P':
        bench_list=P['Forty'].tolist()
        grap()
    if position=='FB':
        bench_list=FB['Forty'].tolist()
        grap()
    if position=='K':
        bench_list=K['Forty'].tolist()
        grap()
    if position=='S':
        bench_list=S['Forty'].tolist()
        grap()
    if position=='EDGE':
        bench_list=EDGE['Forty'].tolist()
        grap()
    if position=='LS':
        bench_list=LS['Forty'].tolist()
        grap()
    
    
#######################################Bench Press Pie Chart
def bench_test():
    def grap():
        under10=0
        reps10_20=0
        reps20_30=0
        reps30_40=0
        reps40andup=0
        total_bench=list()
        for forty in bench_list:
            if forty<10:
                under10+=1 
            if (forty >10) and (forty <20):
                reps10_20+=1
            if (forty >20) and (forty <30):
                reps20_30+=1 
            if (forty >30) and (forty <40):
                reps30_40+=1 
            if (forty >40):
                reps40andup+=1 
        total_bench.append(under10)
        total_bench.append(reps10_20)
        total_bench.append(reps20_30)
        total_bench.append(reps30_40)
        total_bench.append(reps40andup)
        bench_dict=['Under 10 Reps','10-20 Reps','20-30 Reps','30-40 Reps','40 Reps and Above']
        dict_bench = dict(zip(bench_dict, total_bench))
        circle_graph(dict_bench, total_bench)
    
    
   
    position=input('What position group would you like to focus on? ')
    position.lower()
    if position=='CB':
        bench_list=CB['BenchReps'].tolist()
        grap()
    if position=='WR':
        bench_list=WR['BenchReps'].tolist()
        grap()
    if position=='QB':
        bench_list=QB['BenchReps'].tolist()
        grap()
    if position=='RB':
        bench_list=RB['BenchReps'].tolist()
        grap()
    if position=='DE':
        bench_list=DE['BenchReps'].tolist()
        grap()
    if position=='DT':
        bench_list=DT['BenchReps'].tolist()
        grap()
    if position=='OT':
        bench_list=OT['BenchReps'].tolist()
        grap()
    if position=='LB':
        bench_list=LB['BenchReps'].tolist()
        grap()
    if position=='OG':
        bench_list=OG['BenchReps'].tolist()
        grap()
    if position=='TE':
        bench_list=TE['BenchReps'].tolist()
        grap()
    if position=='C':
        bench_list=C['BenchReps'].tolist()
        grap()
    if position=='P':
        bench_list=P['BenchReps'].tolist()
        grap()
    if position=='FB':
        bench_list=FB['BenchReps'].tolist()
        grap()
    if position=='K':
        bench_list=K['BenchReps'].tolist()
        grap()
    if position=='S':
        bench_list=S['BenchReps'].tolist()
        grap()
    if position=='EDGE':
        bench_list=EDGE['BenchReps'].tolist()
        grap()
    if position=='LS':
        bench_list=LS['BenchReps'].tolist()
        grap()
    
    

####################################### Vertical Jump Pie Chart   
def vertical_test():
    def pie(x,y):
        labels = x
        sizes = y
        fig1, ax1 = plt.subplots()
        ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
        ax1.axis('equal')  
        plt.show()
    def grap():
        under10=0
        under20=0
        under30=0
        vert30to35=0
        vert35to40=0
        vert40=0
        total_vert=list()
        for forty in bench_list:
            if forty<20:
                under20+=1 
            if (forty >20) and (forty <30):
                under30+=1
            if (forty >30) and (forty <35):
                vert30to35+=1 
            if (forty >35) and (forty <40):
                vert35to40+=1 
            if (forty >40):
                vert40+=1 
        total_vert.append(under10)
        total_vert.append(under30)
        total_vert.append(vert30to35)
        total_vert.append(vert35to40)
        total_vert.append(vert40)
        vert_dict=['Under 20 inches','20-29 inches','30-35 inches','35-40 inches','40 inches and above']
        dict_vert = dict(zip(vert_dict, total_vert))
        circle_graph(dict_vert, total_vert) 
    position=input('What position group would you like to focus on? ')
    position.lower()
    if position=='CB':
        bench_list=CB['Vertical'].tolist()
        grap()
    if position=='WR':
        bench_list=WR['Vertical'].tolist()
        grap()
    if position=='QB':
        bench_list=QB['Vertical'].tolist()
        grap()
    if position=='RB':
        bench_list=RB['Vertical'].tolist()
        grap()
    if position=='DE':
        bench_list=DE['Vertical'].tolist()
        grap()
    if position=='DT':
        bench_list=DT['Vertical'].tolist()
        grap()
    if position=='OT':
        bench_list=OT['Vertical'].tolist()
        grap()
    if position=='LB':
        bench_list=LB['Vertical'].tolist()
        grap()
    if position=='OG':
        bench_list=OG['Vertical'].tolist()
        grap()
    if position=='TE':
        bench_list=TE['Vertical'].tolist()
        grap()
    if position=='C':
        bench_list=C['Vertical'].tolist()
        grap()
    if position=='P':
        bench_list=P['Vertical'].tolist()
        grap()
    if position=='FB':
        bench_list=FB['Vertical'].tolist()
        grap()
    if position=='K':
        bench_list=K['Vertical'].tolist()
        grap()
    if position=='S':
        bench_list=S['Vertical'].tolist()
        grap()
    if position=='EDGE':
        bench_list=EDGE['Vertical'].tolist()
        grap()
    if position=='LS':
        bench_list=LS['Vertical'].tolist()
        grap()
    
####################################### Height Pie Chart
def height_compare():
    def grap():
        under6=0
        six_six2=0
        six3_5=0
        abovesix5=0
        total_height=list()
        for forty in height_list:
            if forty<72:
                under6+=1 
            if (forty >71) and (forty <74):
                six_six2+=1
            if (forty >74) and (forty <77):
                six3_5+=1 
            if (forty >77):
                abovesix5+=1 
        total_height.append(under6)
        total_height.append(six_six2)
        total_height.append(six3_5)
        total_height.append(abovesix5)
        height_dict=['Under 6ft','6ft-6"2','6"3-6"5','6"5 and above']
        dict_height = dict(zip(height_dict, total_height))
        circle_graph(dict_height, total_height)

    position=input('What position group would you like to focus on? ')
    position.lower()
    if position=='CB':
        bench_list=CB['Ht'].tolist()
        grap()
    if position=='WR':
        bench_list=WR['Ht'].tolist()
        grap()
    if position=='QB':
        bench_list=QB['Ht'].tolist()
        grap()
    if position=='RB':
        bench_list=RB['Ht'].tolist()
        grap()
    if position=='DE':
        bench_list=DE['Ht'].tolist()
        grap()
    if position=='DT':
        bench_list=DT['Ht'].tolist()
        grap()
    if position=='OT':
        bench_list=OT['Ht'].tolist()
        grap()
    if position=='LB':
        bench_list=LB['Ht'].tolist()
        grap()
    if position=='OG':
        bench_list=OG['Ht'].tolist()
        grap()
    if position=='TE':
        bench_list=TE['Ht'].tolist()
        grap()
    if position=='C':
        bench_list=C['Ht'].tolist()
        grap()
    if position=='P':
        bench_list=P['Ht'].tolist()
        grap()
    if position=='FB':
        bench_list=FB['Ht'].tolist()
        grap()
    if position=='K':
        bench_list=K['Ht'].tolist()
        grap()
    if position=='S':
        bench_list=S['Ht'].tolist()
        grap()
    if position=='EDGE':
        bench_list=EDGE['Ht'].tolist()
        grap()
    if position=='LS':
        bench_list=LS['Ht'].tolist()
        grap()

        
####################################### Weight Pie Chart
def weight_compare():
    def grap():
        under185=0
        lb185to200=0
        lb200to214=0
        lb215to229=0
        lb230to259=0
        lb260to285=0
        lb285to300=0
        lb300to315=0
        lb315up=0
        total_weight=list()
        for forty in bench_list:
            if forty<185:
                under185+=1 
            if (forty >184) and (forty <200):
                lb185to200+=1
            if (forty >199) and (forty <215):
                lb200to214+=1 
            if (forty >214) and (forty <230):
                lb215to229+=1 
            if (forty >229) and (forty <260):
                lb230to259+=1
            if (forty >259) and (forty <285):
                lb260to285+=1
            if (forty >284) and (forty <300):
                lb285to300+=1
            if (forty >299) and (forty <315):
                lb300to315+=1
            if (forty >314):
                lb315up+=1
        total_weight.append(under185)
        total_weight.append(lb185to200)
        total_weight.append(lb200to214)
        total_weight.append(lb215to229)
        total_weight.append(lb230to259)
        total_weight.append(lb260to285)
        total_weight.append(lb285to300)
        total_weight.append(lb300to315)
        total_weight.append(lb315up)
        weight_dict=['Under 185lbs','185-199lbs','200-214lbs','215-229lbs','230-259lbs', '260-284lbs', '285-299lbs','300-314lbs', '315lbs and up']
        dict_weight = dict(zip(weight_dict, total_weight))
        circle_graph(dict_weight, total_weight)
    position=input('What position group would you like to focus on? ')
    position.lower()
    if position=='CB':
        bench_list=CB['Wt'].tolist()
        grap()
    if position=='WR':
        bench_list=WR['Wt'].tolist()
        grap()
    if position=='QB':
        bench_list=QB['Wt'].tolist()
        grap()
    if position=='RB':
        bench_list=RB['Wt'].tolist()
        grap()
    if position=='DE':
        bench_list=DE['Wt'].tolist()
        grap()
    if position=='DT':
        bench_list=DT['Wt'].tolist()
        grap()
    if position=='OT':
        bench_list=OT['Wt'].tolist()
        grap()
    if position=='LB':
        bench_list=LB['Wt'].tolist()
        grap()
    if position=='OG':
        bench_list=OG['Wt'].tolist()
        grap()
    if position=='TE':
        bench_list=TE['Wt'].tolist()
        grap()
    if position=='C':
        bench_list=C['Wt'].tolist()
        grap()
    if position=='P':
        bench_list=P['Wt'].tolist()
        grap()
    if position=='FB':
        bench_list=FB['Wt'].tolist()
        grap()
    if position=='K':
        bench_list=K['Wt'].tolist()
        grap()
    if position=='S':
        bench_list=S['Wt'].tolist()
        grap()
    if position=='EDGE':
        bench_list=EDGE['Wt'].tolist()
        grap()
    if position=='LS':
        bench_list=LS['Wt'].tolist()
        grap()
    
    
####################################### Broad Jump Pie Chart
def bj_test():
    def pie(x,y):
        labels = x
        sizes = y  
        fig1, ax1 = plt.subplots()
        ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
        ax1.axis('equal')  
        plt.show()
    def grap():
        above_108=0
        above_1145=0
        above_121=0
        above_1275=0
        above_134=0
        above_1405=0
    
        total_bj=list()
        for bj in bench_list: 
            if (bj >=108) and (bj <114.5):
                above_108=above_108+1 
            if (bj >=114.5) and (bj <121):
                above_1145=above_1145+1 
            if (bj >=121) and (bj <127.5):
                above_121=above_121+1 
            if (bj >=127.5) and (bj <134):
                above_1275=above_1275+1 
            if (bj >=134) and (bj <140.5):
                above_134=above_134+1 
            if (bj >=140.5) and (bj <=147):
                above_1405=above_1405+1 
        total_bj.append(above_108)
        total_bj.append(above_1145)
        total_bj.append(above_121)
        total_bj.append(above_1275)
        total_bj.append(above_134)
        total_bj.append(above_1405)
   
    
        bj_dict=['108-114.5','114.5-121','121-127.5','127.5-134','134-140.5', '140.5-147']
        bjd = dict(zip(bj_dict, total_bj))
        circle_graph(bjd, total_bj)
    
        
    position=input('What position group would you like to focus on? ')
    position.lower()
    if position=='CB':
        bench_list=CB['BroadJump'].tolist()
        grap()
    if position=='WR':
        bench_list=WR['BroadJump'].tolist()
        grap()
    if position=='QB':
        bench_list=QB['BroadJump'].tolist()
        grap()
    if position=='RB':
        bench_list=RB['BroadJump'].tolist()
        grap()
    if position=='DE':
        bench_list=DE['BroadJump'].tolist()
        grap()
    if position=='DT':
        bench_list=DT['BroadJump'].tolist()
        grap()
    if position=='OT':
        bench_list=OT['BroadJump'].tolist()
        grap()
    if position=='LB':
        bench_list=LB['BroadJump'].tolist()
        grap()
    if position=='OG':
        bench_list=OG['BroadJump'].tolist()
        grap()
    if position=='TE':
        bench_list=TE['BroadJump'].tolist()
        grap()
    if position=='C':
        bench_list=C['BroadJump'].tolist()
        grap()
    if position=='P':
        bench_list=P['BroadJump'].tolist()
        grap()
    if position=='FB':
        bench_list=FB['BroadJump'].tolist()
        grap()
    if position=='K':
        bench_list=K['BroadJump'].tolist()
        grap()
    if position=='S':
        bench_list=S['BroadJump'].tolist()
        grap()
    if position=='EDGE':
        bench_list=EDGE['BroadJump'].tolist()
        grap()
    if position=='LS':
        bench_list=LS['BroadJump'].tolist()
        grap()
    
################################################ Cone Pie Chart
def cone_test():
    
    def grap():
        above_628=0
        above_649=0
        above_669=0
        above_690=0
        above_715=0
        above_731=0
    
        total_cone=list()
        for cone in bench_list: 
            if (cone >=6.28) and (cone <6.4865):
                above_628=above_628+1 
            if (cone >=6.4865) and (cone <6.693):
                above_649=above_649+1 
            if (cone >=6.693) and (cone <6.8995):
                above_669=above_669+1 
            if (cone >=6.8995) and (cone <7.106):
                above_690=above_690+1 
            if (cone >=7.106) and (cone <7.3125):
                above_715=above_715+1 
            if (cone >=7.3125) and (cone <=7.52):
                above_731=above_731+1 
        total_cone.append(above_628)
        total_cone.append(above_649)
        total_cone.append(above_669)
        total_cone.append(above_690)
        total_cone.append(above_715)
        total_cone.append(above_731)
   
    
        cone_dict=['6.28-6.4865','6.4865-6.693','6.693-6.8995','6.8995-7.106','7.106-7.3125', '7.3125-7.52']
        coned = dict(zip(cone_dict, total_cone))
        circle_graph(coned, total_cone)

    position=input('What position group would you like to focus on? ')
    position.lower()
    if position=='CB':
        bench_list=CB['Cone'].tolist()
        grap()
    if position=='WR':
        bench_list=WR['Cone'].tolist()
        grap()
    if position=='QB':
        bench_list=QB['Cone'].tolist()
        grap()
    if position=='RB':
        bench_list=RB['Cone'].tolist()
        grap()
    if position=='DE':
        bench_list=DE['Cone'].tolist()
        grap()
    if position=='DT':
        bench_list=DT['Cone'].tolist()
        grap()
    if position=='OT':
        bench_list=OT['Cone'].tolist()
        grap()
    if position=='LB':
        bench_list=LB['Cone'].tolist()
        grap()
    if position=='OG':
        bench_list=OG['Cone'].tolist()
        grap()
    if position=='TE':
        bench_list=TE['Cone'].tolist()
        grap()
    if position=='C':
        bench_list=C['Cone'].tolist()
        grap()
    if position=='P':
        bench_list=P['Cone'].tolist()
        grap()
    if position=='FB':
        bench_list=FB['Cone'].tolist()
        grap()
    if position=='K':
        bench_list=K['Cone'].tolist()
        grap()
    if position=='S':
        bench_list=S['Cone'].tolist()
        grap()
    if position=='EDGE':
        bench_list=EDGE['Cone'].tolist()
        grap()
    if position=='LS':
        bench_list=LS['Cone'].tolist()
        grap()
    
    
####################################### Shuttle Pie Chart
def sh_test():
    def pie(x,y):
        labels = x
        sizes = y  
        fig1, ax1 = plt.subplots()
        ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
        ax1.axis('equal')  
        plt.show()
    def grap():
        one=0
        two=0
        three=0
        four=0
        five=0
    
        total_sh=list()
        for sh in bench_list: 
            if (sh >=3.75) and (sh <3.952):
                one=one+1 
            if (sh >=3.952) and (sh <4.154):
                two=two+1 
            if (sh >=4.154) and (sh <4.356):
                three=three+1 
            if (sh >=4.356) and (sh <4.558):
                four=four+1 
            if (sh >=4.558) and (sh <4.76):
                five=five+1 
         
        total_sh.append(one)
        total_sh.append(two)
        total_sh.append(three)
        total_sh.append(four)
        total_sh.append(five)
    
        sh_dict=['3.75-3.952','3.952-4.154','4.154-4.356','4.356-4.558','4.558-4.76']
        shd = dict(zip(sh_dict, total_sh))
        circle_graph(shd, total_sh)


    position=input('What position group would you like to focus on? ')
    position.lower()
    if position=='CB':
        bench_list=CB['Shuttle'].tolist()
        grap()
    if position=='WR':
        bench_list=WR['Shuttle'].tolist()
        grap()
    if position=='QB':
        bench_list=QB['Shuttle'].tolist()
        grap()
    if position=='RB':
        bench_list=RB['Shuttle'].tolist()
        grap()
    if position=='DE':
        bench_list=DE['Shuttle'].tolist()
        grap()
    if position=='DT':
        bench_list=DT['Shuttle'].tolist()
        grap()
    if position=='OT':
        bench_list=OT['Shuttle'].tolist()
        grap()
    if position=='LB':
        bench_list=LB['Shuttle'].tolist()
        grap()
    if position=='OG':
        bench_list=OG['Shuttle'].tolist()
        grap()
    if position=='TE':
        bench_list=TE['Shuttle'].tolist()
        grap()
    if position=='C':
        bench_list=C['Shuttle'].tolist()
        grap()
    if position=='P':
        bench_list=P['Shuttle'].tolist()
        grap()
    if position=='FB':
        bench_list=FB['Shuttle'].tolist()
        grap()
    if position=='K':
        bench_list=K['Shuttle'].tolist()
        grap()
    if position=='S':
        bench_list=S['Shuttle'].tolist()
        grap()
    if position=='EDGE':
        bench_list=EDGE['Shuttle'].tolist()
        grap()
    if position=='LS':
        bench_list=LS['Shuttle'].tolist()
        grap()
    

def graph_prompt():
    testdraft = ' '
    while True:
        
        testdraft = input('What event would you like to focus on? (Ht, Wt, Forty, Vertical, BenchReps, BroadJump, Cone, Shuttle)')
        testdraft.lower()
        if testdraft == 'quit':
            break
            continue
        if testdraft=='Ht':
            height_compare()
        if testdraft=='Wt':
            weight_compare()
        if testdraft=='Forty':
            forty_test()
        if testdraft=='Vertical':
            vertical_test()
        if testdraft=='BenchReps':
            bench_test()
        if testdraft=='BroadJump':
            bj_test()
        if testdraft=='Cone':
            cone_test()
        if testdraft=='Shuttle':
            sh_test()

# %%
graph_prompt()
